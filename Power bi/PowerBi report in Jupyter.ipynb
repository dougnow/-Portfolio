# %%
from IPython.display import IFrame

# %%
Dashboard = IFrame(src="https://app.powerbi.com/view?r=eyJrIjoiOGIzMWM0ZTMtYjJlOS00ZTEwLThkYjMtYjA3NWE2YTdkZTM4IiwidCI6IjU5ZjZlMWI5LTI4ODQtNDQ1OC1iMGM5LWM4ZWY1YmJhMmY0NCJ9", width =1000, height= 600)

# %%
display(Dashboard)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="https://app.powerbi.com/view?r=eyJrIjoiOGIzMWM0ZTMtYjJlOS00ZTEwLThkYjMtYjA3NWE2YTdkZTM4IiwidCI6IjU5ZjZlMWI5LTI4ODQtNDQ1OC1iMGM5LWM4ZWY1YmJhMmY0NCJ9"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![image.png](attachment:image.png)

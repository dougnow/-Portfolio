# %% [markdown]
# ## How to download YouTube videos with Python
#
# RDouglas   @dougnow
#
#
#
# 1.   pip install pytube
# 2.   import pytube
#
# please check pytube documentation:
# https://pytube.io/en/latest/index.html

# %% [markdown]
# Maybe you'll require install the package

# %%
pip install pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 56 kB 1.5 MB/s
# ...

# %% [markdown]
# Now import  pytube

# %%
#import pytube library to download videos
import pytube

# %% [markdown]
# Finally structure the code:
#
#
# *   url
# *   path
# *   line code

# %%
# ask for video URL
url = input("Enter video url: ")

#specify the sorage path of video 
path = "E:"

#magic line to download the video
pytube.YouTube(url).streams.get_highest_resolution().download(path)
# Out:
# Enter video url: https://www.youtube.com/watch?v=xQ_IQS3VKjA&t=33s
# '/content/E:/Danny Macaskill The Ridge.mp4'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

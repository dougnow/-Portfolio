# %%
import streamlit as st
import joblib
import numpy as np

# Cargar el modelo entrenado
modelo = joblib.load('modelo_SVC_entrenado.pkl')

st.title("Predicción de Resignación de Empleados")

# Inputs del usuario
education = st.selectbox("Education", ["Bachelors", "Masters", "PHD"])
joining_year = st.number_input("Joining Year", min_value=2000, max_value=2025, step=1)
city = st.selectbox("City", ["Bangalore", "Pune", "New Delhi"])
payment_tier = st.selectbox("Payment Tier", [1, 2, 3])
age = st.number_input("Age", min_value=18, max_value=60)
gender = st.selectbox("Gender", ["Male", "Female"])
ever_benched = st.selectbox("Ever Benched", ["No", "Yes"])
experience = st.number_input("Experience in Current Domain", min_value=0, max_value=10)

# Convertir inputs categóricos a valores numéricos
education_mapping = {"Bachelors": 0, "Masters": 1, "PHD": 2}
city_mapping = {"Bangalore": 0, "Pune": 1, "New Delhi": 2}
gender_mapping = {"Male": 0, "Female": 1}
ever_benched_mapping = {"No": 0, "Yes": 1}

input_data = np.array([
    education_mapping[education],
    joining_year,
    city_mapping[city],
    payment_tier,
    age,
    gender_mapping[gender],
    ever_benched_mapping[ever_benched],
    experience
]).reshape(1, -1)

# Predicción
if st.button("Predecir"):
    resultado = modelo.predict(input_data)
    if resultado[0] == 1:
        st.write("El empleado tiene alta probabilidad de renunciar.")
    else:
        st.write("El empleado tiene baja probabilidad de renunciar.")
# Out:
# 2024-11-08 17:53:44.917 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.220
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Rdouglas\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-08 17:53:46.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.225 Session state does not function when running a script without `streamlit run`
# 2024-11-08 17:53:46.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 17:53:46.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

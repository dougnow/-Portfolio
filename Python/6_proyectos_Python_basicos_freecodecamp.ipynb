# %% [markdown]
# ## 6 Proyectos de Python Básicos - Curso Completo Paso a Paso
#
# **Realizado por Richard Douglas G.   dougnow**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# se puede observar en el siguiente link https://www.youtube.com/watch?v=tWnyBD2src0&t=280s

# %% [markdown]
# **Cómo ejecutar scripts de Python**
# https://pythones.net/archivos-py-scripts-de-python/

# %% [markdown]
# ## 1- Madlibs - Historias Locas :
# **consiste en ingresar texto e ir completando la historia**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Como usar Strings
organizacion = 'freeCodeCamp'

# %%
print(organizacion)
# Out:
# freeCodeCamp

# %%
print('Aprende a programar con '+ organizacion)
# Out:
# Aprende a programar con freeCodeCamp

# %%
print('Aprende a programar con {}'.format(organizacion))
# Out:
# Aprende a programar con freeCodeCamp

# %%
print(f"Aprende a programar con {organizacion}") # f-string
# Out:
# Aprende a programar con freeCodeCamp

# %% [markdown]
# **Historias Locas**

# %%
adj = input('Ingrese un Adjetivo: ')
verbo1= input('Ingrese un verbo: ')
verbo2= input('Ingrese un verbo: ')
adj = input('ingrese un adjetivo: ')
sustantivo_plural=input('ingrese un sustantivo: ')
# Out:
# Ingrese un Adjetivo: Interesante
# Ingrese un verbo: emociona
# Ingrese un verbo: resolver
# ingrese un adjetivo: programar
# ingrese un sustantivo: metas

# %%
madlib =f"Programar es tan {adj}! Siempre me emociona porque me encanta {verbo1} problemas. !Aprende a {verbo2} con FreeCodeCamp y alcanza tus {sustantivo_plural} "

# %%
print(madlib)
# Out:
# Programar es tan programar! Siempre me emociona porque me encanta emociona problemas. !Aprende a resolver con FreeCodeCamp y alcanza tus metas

# %% [markdown]
# ## 2- Adivina el Número
# **Quien debe acertar el número es el usuario**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random # se mporta esto para generar el número aleatorio

# %%
def adivina_el_numero(x):


    print("==============================")
    print("    Bienvenido(a) al juego    ")
    print("==============================")
    print("Tu meta es adivinar el número generado por la computadora")

    numero_aleatorio = random.randint(1, x)  # genera un numero entero aleatorio entre 1 y x.

    prediccion = 0  # inicialmente su valor será cero para que no coincida de ninguna manera con la posibilidad del número aleatorio

    while prediccion != numero_aleatorio:
      #el usuario ingresa un numero
      prediccion = int(input(f"Adivina un número entre 1 y {x}: "))  # f-string este tipo de cadena, permite eemplazar una variable o expresion de forma más precisa 

      if prediccion < numero_aleatorio:
          print("Intenta otra vez, Este número es muy pequeño.")
      elif prediccion > numero_aleatorio:
          print("Intenta otra vez, Este número es muy grande.")

    print(f"¡Felicitaciones! Has Acertado el número {numero_aleatorio} correctamente.")


adivina_el_numero(10)
# Out:
# ...
#     Bienvenido(a) al juego
# ...
# Tu meta es adivinar el número generado por la computadora
# Adivina un número entre 1 y 10: 8
# Intenta otra vez, Este número es muy grande.
# Adivina un número entre 1 y 10: 9
# Intenta otra vez, Este número es muy grande.
# Adivina un número entre 1 y 10: 1
# Intenta otra vez, Este número es muy pequeño.
# Adivina un número entre 1 y 10: 2
# Intenta otra vez, Este número es muy pequeño.
# Adivina un número entre 1 y 10: 3
# Intenta otra vez, Este número es muy pequeño.
# Adivina un número entre 1 y 10: 4
# Intenta otra vez, Este número es muy pequeño.
# Adivina un número entre 1 y 10: 5
# Intenta otra vez, Este número es muy pequeño.
# Adivina un número entre 1 y 10: 6
# ¡Felicitaciones! Has Acertado el número 6 correctamente.

# %%
def adivina_el_numero(x):


    print("==============================")
    print("    Bienvenido(a) al juego    ")
    print("==============================")
    print("Tu meta es adivinar el número generado por la computadora")

    numero_aleatorio = random.randint(1, x)  # genera un numero entero aleatorio entre 1 y x.

    prediccion = 0  # inicialmente su valor será cero para que no coincida de ninguna manera con la posibilidad del número aleatorio

    while prediccion != numero_aleatorio:
      #el usuario ingresa un numero
      prediccion = int(input(f"Adivina un número entre 1 y {x}: "))  # f-string este tipo de cadena, permite eemplazar una variable o expresion de forma más precisa 

      if prediccion < numero_aleatorio:
          print("Intenta otra vez, Este número es muy pequeño.")
      elif prediccion > numero_aleatorio:
          print("Intenta otra vez, Este número es muy grande.")

    print(f"¡Felicitaciones! Has Acertado el número {numero_aleatorio} correctamente.")


adivina_el_numero(10)
# Out:
# ...
#     Bienvenido(a) al juego
# ...
# Tu meta es adivinar el número generado por la computadora
# Adivina un número entre 1 y 10: 8
# Intenta otra vez, Este número es muy grande.
# Adivina un número entre 1 y 10: 1
# Intenta otra vez, Este número es muy pequeño.
# Adivina un número entre 1 y 10: 5
# Intenta otra vez, Este número es muy grande.
# Adivina un número entre 1 y 10: 4
# Intenta otra vez, Este número es muy grande.
# Adivina un número entre 1 y 10: 3
# Intenta otra vez, Este número es muy grande.
# Adivina un número entre 1 y 10: 2
# ¡Felicitaciones! Has Acertado el número 2 correctamente.

# %%
C:\Users\Rdouglas\Practicas personales > python adivina_el_numero.py
# Out:
#   Input In [1]
#     C:\Users\Rdouglas\Practicas personales > python adivina_el_numero.py
#                                                                        ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# **ver la documentacion de python sobre números random** https://docs.python.org/es/3/library/random.html
#
# random.randint(a, b)
# Retorna un entero aleatorio N tal que a <= N <= b. Alias de randrange(a, b+1)

# %% [markdown]
# ## 3-Adivina el Número
# **En este caso la computadora buscará acertar el número**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random # se mporta esto para generar el número aleatorio
# se inicia definiendo una funcion adivina el numero
def adivina_el_numero_computadora(x):


  print("==========================================")
  print("       ¡  Bienvenido(a) al juego !        ")
  print("==========================================")
  print(f"Selecciona un numero entre 1 y {x} para quela computadora intente adivinarlo")

  limite_inferior = 1 # [1,x]
  limite_superior = x

  respuesta = "" # se debe crear un caracter vacío, y la computadora intera varias veces para atinar el valor
  while respuesta != "c": #se usa el ciclo while para que el bucle se repita varias veces necesarias
        # generar una prediccion
        if limite_inferior != limite_superior: 
            prediccion = random.randint(limite_inferior, limite_superior)
        else:
            prediccion= limite_inferior #tambien podría ser el limite superior
      #obtener una respuesta del usuario
        respuesta= input(f"Mi prediccion es {prediccion}. Si es muy alta, ingresa (A). Si es muy baja, ingresa(B). Si es correcta, ingresa (C): ").lower()


        if respuesta == "a":
           limite_superior = prediccion - 1
        elif respuesta == "b":
           limite_inferior = prediccion + 1
  print(f"Siiiiiiiiiiiii ¡Felicitaciones! la computadora acertó el numero correctamente  {prediccion} .")

        #intervalo inicial: [1,10]
        #Prediccion :6
        #Respuesta : "a"
        #Intervalo: [1,6]


adivina_el_numero_computadora(10)
# Out:
# ...
#        ¡  Bienvenido(a) al juego !
# ...
# Selecciona un numero entre 1 y 10 para quela computadora intente adivinarlo
# Mi prediccion es 9. Si es muy alta, ingresa (A). Si es muy baja, ingresa(B). Si es correcta, ingresa (C): A
# Mi prediccion es 8. Si es muy alta, ingresa (A). Si es muy baja, ingresa(B). Si es correcta, ingresa (C): A
# Mi prediccion es 4. Si es muy alta, ingresa (A). Si es muy baja, ingresa(B). Si es correcta, ingresa (C): A
# Mi prediccion es 2. Si es muy alta, ingresa (A). Si es muy baja, ingresa(B). Si es correcta, ingresa (C): C
# Siiiiiiiiiiiii ¡Felicitaciones! la computadora acertó el numero correctamente  2 .

# %% [markdown]
# ## 4- Piedra, Papel o tijera
# **el popular juego para generar desempates entre amigos**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random 
# Iniciamos creando una funcion
def jugar():
    usuario = input("Escoge una opción: 'pi' para piedra, 'pa' para papel, 'ti' para tijeras.\n").lower()  # se crea la variable es corresponde al valor que ingresa el usuario. \n indica donde termina la linea
    computadora = random.choice(['pi','pa','ti'])  # se crea una variable para la computadora, y se genera un random para que busque un vlaor random de una lista determinada random.choice

    if usuario == computadora:
        return ("¡Empate!'", {computadora})
    if gano_el_jugador(usuario, computadora):  # se crea una funcion que compruba quien gana
        return ( "'¡Ganaste!'", {computadora})

    return ("'¡Perdiste!'",{computadora})


def gano_el_jugador(jugador, oponente):
    # retornar True (verdadero) si gana el jugador.
    # Piedra le gana tijera (pi > ti)
    # Tijera le gana a papel (ti > pa)
    # Papel le gana a piedra (pa > pi)
    if ((jugador == 'pi' and oponente == 'ti')
       or (jugador == 'ti' and oponente == 'pa')
       or (jugador == 'pa' and oponente == 'pi')):
       return True
    else:
       return False
      

print(jugar())
# Out:
# Escoge una opción: 'pi' para piedra, 'pa' para papel, 'ti' para tijeras.
# pa
# ("'¡Perdiste!'", {'ti'})

# %%
import random 
# Iniciamos creando una funcion

def jugar():
    usuario = input("Escoge una opción: 'pi' para piedra, 'pa' para papel, 'ti' para tijeras.\n").lower()  # se crea la variable es corresponde al valor que ingresa el usuario. \n indica donde termina la linea
    computadora = random.choice(['pi','pa','ti'])  # se crea una variable para la computadora, y se genera un random para que busque un vlaor random de una lista determinada random.choice

    if usuario == computadora:
        return ('¡Empate!', 'la computadora eligió la opción '+ computadora)
    if gano_el_jugador(usuario, computadora):  # se crea una funcion que compruba quien gana
        return ( '¡Ganaste!', 'la computadora eligió la opción '+ computadora)

    return ('¡Perdiste!', 'la computadora eligió la opción '+ computadora)


def gano_el_jugador(jugador, oponente):
        # retornar True (verdadero) si gana el jugador.
        # Piedra le gana tijera (pi > ti)
        # Tijera le gana a papel (ti > pa)
        # Papel le gana a piedra (pa > pi)
    if ((jugador == 'pi' and oponente == 'ti')
        or (jugador == 'ti' and oponente == 'pa')
        or (jugador == 'pa' and oponente == 'pi')):
        return True
    else:
        return False
      
print(jugar())
# Out:
# Escoge una opción: 'pi' para piedra, 'pa' para papel, 'ti' para tijeras.
# pa
# ('¡Empate!', 'la computadora eligió la opción pa')

# %%
import random 
# Iniciamos creando una funcion
def jugar():
    usuario = input("Escoge una opción: 'pi' para piedra, 'pa' para papel, 'ti' para tijeras.\n").lower()  # se crea la variable es corresponde al valor que ingresa el usuario. \n indica donde termina la linea
    computadora = random.choice(['pi','pa','ti'])  # se crea una variable para la computadora, y se genera un random para que busque un vlaor random de una lista determinada random.choice

    if usuario == computadora:
        return '¡Empate!'
    if gano_el_jugador(usuario, computadora):  # se crea una funcion que compruba quien gana
        return '¡Ganaste!'

    return '¡Perdiste!'


def gano_el_jugador(jugador, oponente):
    # retornar True (verdadero) si gana el jugador.
    # Piedra le gana tijera (pi > ti)
    # Tijera le gana a papel (ti > pa)
    # Papel le gana a piedra (pa > pi)
    if ((jugador == 'pi' and oponente == 'ti')
       or (jugador == 'ti' and oponente == 'pa')
       or (jugador == 'pa' and oponente == 'pi')):
       return True
    else:
       return False
      

print(jugar())
# Out:
# Escoge una opción: 'pi' para piedra, 'pa' para papel, 'ti' para tijeras.
# pa
# ¡Empate!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random 
# Iniciamos creando una funcion

def jugar():
    usuario = input("Escoge una opción: 'pi' para piedra, 'pa' para papel, 'ti' para tijeras.\n").lower()  # se crea la variable es corresponde al valor que ingresa el usuario. \n indica donde termina la linea
    computadora = random.choice(['pi','pa','ti'])  # se crea una variable para la computadora, y se genera un random para que busque un vlaor random de una lista determinada random.choice

    if usuario == computadora:
        return ('¡Empate!', 'la computadora eligió la opción '+ computadora)
    if gano_el_jugador(usuario, computadora):  # se crea una funcion que compruba quien gana
        return ( '¡Ganaste!', 'la computadora eligió la opción '+ computadora)

    return ('¡Perdiste!', 'la computadora eligió la opción '+ computadora)


def gano_el_jugador(jugador, oponente):
        # retornar True (verdadero) si gana el jugador.
        # Piedra le gana tijera (pi > ti)
        # Tijera le gana a papel (ti > pa)
        # Papel le gana a piedra (pa > pi)
    if ((jugador == 'pi' and oponente == 'ti')
        or (jugador == 'ti' and oponente == 'pa')
        or (jugador == 'pa' and oponente == 'pi')):
        return True
    else:
        return False
      
print(jugar())
# Out:
# Escoge una opción: 'pi' para piedra, 'pa' para papel, 'ti' para tijeras.
# pa
# ('¡Perdiste!', 'la computadora eligió la opción ti')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5-El Ahorcado

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
palabras = ["aire", "ojos", "piel", "anteojos", "joven", "viejo", "alto", "bajo", "pequeño", "gordo", "delgado", "bella", "azul", "verde", "negro", "sombrero", "guantes", "corbata", "gemelos", "paraguas", "plata", "oro", "perla", "diamante", "esmeralda", "anillo", "pulsera", "reloj", "elegante", "sencillo", "chaqueta", "traje", "camisa", "zapatos", "pelo", "maquillaje", "peine", "dedo", "hueso", "cara", "ojo", "calor", "ambulancia", "enfermera", "farmacia", "vitaminas", "pastillas", "dentista", "ciego", "correr", "caminar", "regresar", "saltar", "fin", "cerrar", "nombre", "mujer", "hombre", "soltero", "novio", "nacer", "vivir", "edad", "anciana","trabajar", "cobrar", "azafata", "artista", "panadero", "carpintero", "cocinero", "maestro", "bombero", "juez", "modelo", "monje", "pintor", "piloto", "secretaria", "taxista", "escritor", "jefe", "aprendiz", "jubilado", "empleo", "industria", "taller", "tienda", "vacaciones", "sueldo", "impuesto", "huelga", "obedecer", "locura", "humor", "inteligencia", "orgullo", "timidez", "valiente", "aburrido", "loco", "divertido", "bueno", "feliz", "amable", "pobre", "serio", "extraño", "gritar", "llorar", "suspirar", "preocupado", "risa", "amor", "suerte", "enamorado", "ver", "apagar", "luz", "color", "lupa", "microscopio", "claro", "cantar", "silbar", "voz", "eco", "trueno", "altavoz", "radio", "auricular", "liso", "comer", "dulce", "salado", "perfume", "despertarse", "vestirse", "desayunar", "leer", "dormirse", "toalla", "cobija", "almuerzo", "sopa", "agua", "leche", "jugo", "sal", "pimienta", "vinagre", "ajo", "perejil", "menta", "canela", "mayonesa", "pan", "mantequilla", "miel", "manzana", "pera", "durazno", "cereza", "papa", "lechuga", "arroz", "pollo", "pavo", "hamburguesa", "camarones", "tortilla", "espagueti", "sopa", "helado", "chocolate", "galletas", "bombones", "limpiar", "cortar", "hervir", "planchar", "aspiradora", "plancha", "horno", "abrelatas", "vajilla", "vaso", "cafetera", "azucarera", "comprar", "gastar", "vender", "barato", "caro", "gratis", "cliente", "bolsa", "precio", "recibo", "ascensor", "esquiar", "ciclismo", "golf", "pelota", "tenis", "bicicleta", "estadio", "gol", "torneo", "leer", "dibujar", "cantar", "bailar", "libro", "revista", "clavo", "cine", "pala", "cocina", "hielo", "coro", "piano", "cartas", "pesca", "radio", "noticias", "televisor", "documental", "anuncio", "aplaudir", "teatro", "circo", "mago", "disco", "portero", "propina", "regalo", "fiesta", "vela", "alfombra", "puerta", "ventana", "cortina", "escritorio", "cuadro", "juguete", "alquiler", "mudanza", "casa", "pared", "chimenea", "comedor", "plaza", "calle", "estacionamiento", "parque", "puente", "puerto", "edificio", "escuela", "museo", "estatua", "fuente", "turista", "mendigo", "manejar", "acelerar", "frenar", "cruzar", "reparar", "conductor", "multa", "atasco", "carretera", "peaje", "curva", "florecer", "campo", "bosque", "huerto", "selva", "tronco", "rama", "flor", "hoja", "musgo", "cedro", "roble", "pino", "nogal", "naranjo", "tallo", "clavel", "margarita", "amapola", "rosa", "girasol", "violeta", "gato", "perro", "vaca", "pato", "oveja", "conejo", "pez", "oso", "jirafa", "erizo", "mariposa", "foca", "tigre", "cobra", "almeja", "paloma", "cisne", "mosquito", "hormiga", "llover", "nevar", "nublado", "soleado", "clima", "rayo", "nieve", "sol", "viento", "padre", "madre", "hijo", "abuela", "estudioso", "aula", "tiza", "regla", "computadora", "diccionario"]

# %%
vidas_diccionario_visual = {
        0: """
                ___________
               | /        | 
               |/        ( )
               |          |
               |         / \\
               |
           """,
        1: """
                ___________
               | /        | 
               |/        ( )
               |          |
               |         / 
               |
            """,
        2: """
                ___________
               | /        | 
               |/        ( )
               |          |
               |          
               |
            """,
        3: """
                ___________
               | /        | 
               |/        ( )
               |          
               |          
               |
            """,
        4: """
                ___________
               | /        | 
               |/        
               |          
               |          
               |
            """,
        5: """
                ___________
               | /        
               |/        
               |          
               |          
               |
            """,
        6: """
               |
               |
               |
               |
               |
            """,
        7: "",
    }

# %%
# este juego consiste en ir tratando de "adivinar" la palabra secreta


# primero se debe crear la funcion

import random
import string

from palabras import palabras
from vidas_diccionario_visual import vidas_diccionario_visual

def obtener_palabra_validad(lista_palabras):
    #Seleccionar una palabra al azar de la lista
    #de palabras validas
    
    palabra= random.choice(palabras)
    
    while '-' in palabra or ' ' in palabra:
        palabra = random.choice(palabras)
    
    
    return palabra.upper()


def ahorcado():
    
    print("=========================================")
    print("  ¡Bienvenido(a) al juego del Ahorcado! ")
    print("=========================================")
    
    palabra = obtener_palabra_validad(palabras)
    # se debe crear grupos importantes: letras adivinadas, letras por adivinar y el abecedario
    
    letras_por_adivinar = set(palabra)# inicialmente convertir la palabra en un conjunto {''} elementos individuales y no se repiten
    letras_adivinadas= set() # este conjunto estará inicialmente vacío
    abecedario = set(string.ascii_uppercase)
    
    vidas = 7
    
    while len(letras_por_adivinar) > 0 and vidas > 0:
        print(f"Te quedan {vidas} vidas y has usado estas letras : {' '.join(letras_adivinadas)}")
        
        # Mostrar el estado actual de la palabra
        palabra_lista = [letra if letra in letras_adivinadas else '-' for letra in palabra] # list comprehension
        print(vidas_diccionario_visual[vidas])
        print(f"Palabra: {' '.join (palabra_lista)}") # muestra las letras separadas por espacios
    
        letra_usuario =input("Escoge una letra: ").upper()
    
        #si la letra escogida por el usuario está en el abecedario y no está en el conjunto de letras
        #que ya se han ingresado, se añade la letra al conjunto de letras ingresadas.
        if letra_usuario in abecedario - letras_adivinadas:
            letras_adivinadas.add(letra_usuario)
        
            #si la letra está en la palabra o no
            #quitar la letra del conjunto de letras pendientes por adivinar, sino est´ala palabra quitar una vida
            if letra_usuario in letras_por_adivinar:
                letras_por_adivinar.remove(letra_usuario)
                print('')
            else:
                vidas= vidas - 1
                print(f"\nTu letra, {letra_usuario} no está en la palabra")
        #si la letra escogida por el usario ya fue ingresada              
        elif letra_usuario in letras_adivinadas:
            print("\nYa escogiste esa letra. Por favor escoge una letra nueva.")
        else:
            print("\nEsta letra no es válida.")
                  
    # El juego llega a esta línea cuando se adivinan todas las letras de la palabra o cuando se agotan las vidas del jugador
    if vidas == 0:
        print(vidas_diccionario_visual[vidas])
        print(f" ¡Ahoracado!  Perdiste. Lo lamento mucho. la palabra era: {palabra}")
    else:
        print(f"¡Excelente! Adivinaste la palabra ¡{palabra}!")

              
ahorcado()
# Out:
# ...
#   ¡Bienvenido(a) al juego del Ahoracado!
# ...
# Te quedan 7 vidas y has usado estas letras :
#
# Palabra: - - - - - -
# Escoge una letra: a
#
# Te quedan 7 vidas y has usado estas letras : A
#
# Palabra: - - - - - A
# Escoge una letra: e
#
# Tu letra, E no está en la palabra
# Te quedan 6 vidas y has usado estas letras : E A
#
#                |
#                |
#                |
#                |
#                |
#
# Palabra: - - - - - A
# Escoge una letra: l
#
# Tu letra, L no está en la palabra
# Te quedan 5 vidas y has usado estas letras : E A L
#
#                 ___________
#                | /
#                |/
#                |
#                |
#                |
#
# Palabra: - - - - - A
# Escoge una letra: b
#
# Te quedan 5 vidas y has usado estas letras : B E A L
#
#                 ___________
#                | /
#                |/
#                |
#                |
#                |
#
# Palabra: - - B - - A
# Escoge una letra: c
#
# ...

# %%
# este juego consiste en ir tratando de "adivinar" la palabra secreta


# primero se debe crear la funcion

import random
import string

from palabras import palabras
from vidas_diccionario_visual import vidas_diccionario_visual

def obtener_palabra_validad(lista_palabras):
    #Seleccionar una palabra al azar de la lista
    #de palabras validas
    
    palabra= random.choice(palabras)
    
    while '-' in palabra or ' ' in palabra:
        palabra = random.choice(palabras)
    
    
    return palabra.upper()


def ahorcado():
    
    print("=========================================")
    print("  ¡Bienvenido(a) al juego del Ahorcado! ")
    print("=========================================")
    
    palabra = obtener_palabra_validad(palabras)
    # se debe crear grupos importantes: letras adivinadas, letras por adivinar y el abecedario
    
    letras_por_adivinar = set(palabra)# inicialmente convertir la palabra en un conjunto {''} elementos individuales y no se repiten
    letras_adivinadas= set() # este conjunto estará inicialmente vacío
    abecedario = set(string.ascii_uppercase)
    
    vidas = 7
    
    while len(letras_por_adivinar) > 0 and vidas > 0:
        print(f"Te quedan {vidas} vidas y has usado estas letras : {' '.join(letras_adivinadas)}")
        
        # Mostrar el estado actual de la palabra
        palabra_lista = [letra if letra in letras_adivinadas else '-' for letra in palabra] # list comprehension
        print(vidas_diccionario_visual[vidas])
        print(f"Palabra: {' '.join (palabra_lista)}") # muestra las letras separadas por espacios
    
        letra_usuario =input("Escoge una letra: ").upper()
    
        #si la letra escogida por el usuario está en el abecedario y no está en el conjunto de letras
        #que ya se han ingresado, se añade la letra al conjunto de letras ingresadas.
        if letra_usuario in abecedario - letras_adivinadas:
            letras_adivinadas.add(letra_usuario)
        
            #si la letra está en la palabra o no
            #quitar la letra del conjunto de letras pendientes por adivinar, sino est´ala palabra quitar una vida
            if letra_usuario in letras_por_adivinar:
                letras_por_adivinar.remove(letra_usuario)
                print('')
            else:
                vidas= vidas - 1
                print(f"\nTu letra, {letra_usuario} no está en la palabra")
        #si la letra escogida por el usario ya fue ingresada              
        elif letra_usuario in letras_adivinadas:
            print("\nYa escogiste esa letra. Por favor escoge una letra nueva.")
        else:
            print("\nEsta letra no es válida.")
                  
    # El juego llega a esta línea cuando se adivinan todas las letras de la palabra o cuando se agotan las vidas del jugador
    if vidas == 0:
        print(vidas_diccionario_visual[vidas])
        print(f" ¡Ahoracado!  Perdiste. Lo lamento mucho. la palabra era: {palabra}")
    else:
        print(f"¡Excelente! Adivinaste la palabra ¡{palabra}!")

              
ahorcado()
# Out:
# ...
#   ¡Bienvenido(a) al juego del Ahoracado!
# ...
# Te quedan 7 vidas y has usado estas letras :
#
# Palabra: - - -
# Escoge una letra: 4
#
# Esta letra no es válida.
# Te quedan 7 vidas y has usado estas letras :
#
# Palabra: - - -
# Escoge una letra: q
#
# Tu letra, Q no está en la palabra
# Te quedan 6 vidas y has usado estas letras : Q
#
#                |
#                |
#                |
#                |
#                |
#
# Palabra: - - -
# Escoge una letra: r
#
# Tu letra, R no está en la palabra
# Te quedan 5 vidas y has usado estas letras : R Q
#
#                 ___________
#                | /
#                |/
#                |
#                |
#                |
#
# Palabra: - - -
# Escoge una letra: t
#
# Tu letra, T no está en la palabra
# Te quedan 4 vidas y has usado estas letras : T R Q
#
#                 ___________
#                | /        |
#                |/
#                |
#                |
#                |
#
# Palabra: - - -
# ...

# %% [markdown]
# ## 6- Busqueda Binaria
# ![image.png](attachment:image.png)

# %%
# comparar la eficiencia de naive search   y luego con una busqueda binaria
import random 
import time # para realizar conteo de tiempo

def busqueda_ingenua(lista, objetivo):# creAR UN ALISTA Y EN ESA LISTA SABER SI EL VALOR SE ENCUENTRA OBJETIVO/TARGET
    for i in range(len(lista)): #range(len(lista)) va a recorrer de 0,1,2,3   por ejemplo recorrer el indice
        if lista[i] == objetivo:
            return i   # si se cumple retornar el valor de i
    return -1  # sino se cumple regresa valor -1

# %%
mi_lista=[1,3,5,10,12]
print(busqueda_ingenua(mi_lista,10))
# Out:
# 3

# %% [markdown]
# el indice en donde se encuentra el valor de 10. corresponde a 3 . correcto

# %%
mi_lista=[1,3,5,10,12]
print(busqueda_ingenua(mi_lista,11))
# Out:
# -1

# %% [markdown]
# como el número 11 no se encuentra en la lista, el indice indicado es -1.

# %% [markdown]
# ### Implementar el algoritmo de busqueda binaria para mejorar el tiempo de busqueda
#
# 1- la lista debe estar ordenada de forma ascendente de lo contrario no funciona
#
# 2- agregar un limite inferior y un limite superior

# %%
def busqueda_binaria(lista, objetivo, limite_inferior=None, limite_superior=None):
    if limite_inferior is None:
        limite_inferior = 0 # inicio de la lista
    if limite_superior is None:
        limite_superior = len(lista)-1 # Final de las lista 
        
    if limite_superior < limite_inferior:
        return -1

    punto_medio = (limite_inferior + limite_superior) //2   # permite buscar el punto medio de la lista
    
    if lista[punto_medio] == objetivo:
        return punto_medio
    elif objetivo < lista[punto_medio]:
        return busqueda_binaria(lista,objetivo, limite_inferior,punto_medio-1)
    else:
        return busqueda_binaria(lista,objetivo, punto_medio+1, limite_superior)
    
    
if __name__=='__main__':
    mi_lista=[1,3,5,10,12]
    print(busqueda_binaria(mi_lista,12))
# Out:
# 4

# %%
def busqueda_binaria(lista, objetivo, limite_inferior=None, limite_superior=None):
    if limite_inferior is None:
        limite_inferior = 0 # inicio de la lista
    if limite_superior is None:
        limite_superior = len(lista)-1 # Final de las lista 
        
    if limite_superior < limite_inferior:
        return -1

    punto_medio = (limite_inferior + limite_superior) //2   # permite buscar el punto medio de la lista
    
    if lista[punto_medio] == objetivo:
        return punto_medio
    elif objetivo < lista[punto_medio]:
        return busqueda_binaria(lista,objetivo, limite_inferior,punto_medio-1)
    else:
        return busqueda_binaria(lista,objetivo, punto_medio+1, limite_superior)
    
    
if __name__=='__main__':
    mi_lista=[1,3,5,10,12]
    print(busqueda_binaria(mi_lista,7))
# Out:
# -1

# %%
def busqueda_binaria(lista, objetivo, limite_inferior=None, limite_superior=None):
    if limite_inferior is None:
        limite_inferior = 0 # inicio de la lista
    if limite_superior is None:
        limite_superior = len(lista)-1 # Final de las lista 
        
    if limite_superior < limite_inferior:
        return -1

    punto_medio = (limite_inferior + limite_superior) //2   # permite buscar el punto medio de la lista
    
    if lista[punto_medio] == objetivo:
        return punto_medio
    elif objetivo < lista[punto_medio]:
        return busqueda_binaria(lista,objetivo, limite_inferior,punto_medio-1)
    else:
        return busqueda_binaria(lista,objetivo, punto_medio+1, limite_superior)
    
    
if __name__=='__main__':
    #crear una lista ordenada aleatoria de 1000 elementos
    tamano =1000
    conjunto_inicial =set()
    
    
    while len(conjunto_inicial) < tamano:
        conjunto_inicial.add(random.randint(-3*tamano,3*tamano))
    
    lista_ordenada = sorted(list(conjunto_inicial))
    
    # medir el tiempo de busqueda ingenua
    
    inicio = time.time()
    for objetivo in lista_ordenada:
        busqueda_ingenua(lista_ordenada, objetivo)
    fin= time.time()
    print(f"Tiempo de busqueda ingenua:{fin - inicio} segundos.")
     
    
    #medir el tiempo de busqueda binaria
    inicio = time.time()
    for objetivo in lista_ordenada:
        busqueda_binaria(lista_ordenada, objetivo)
    fin= time.time()
    print(f"Tiempo de busqueda binaria:{fin - inicio} segundos.")
# Out:
# Tiempo de busqueda ingenua:0.022937774658203125 segundos.
# Tiempo de busqueda binaria:0.0017745494842529297 segundos.

# %%
def busqueda_binaria(lista, objetivo, limite_inferior=None, limite_superior=None):
    if limite_inferior is None:
        limite_inferior = 0 # inicio de la lista
    if limite_superior is None:
        limite_superior = len(lista)-1 # Final de las lista 
        
    if limite_superior < limite_inferior:
        return -1

    punto_medio = (limite_inferior + limite_superior) //2   # permite buscar el punto medio de la lista
    
    if lista[punto_medio] == objetivo:
        return punto_medio
    elif objetivo < lista[punto_medio]:
        return busqueda_binaria(lista,objetivo, limite_inferior,punto_medio-1)
    else:
        return busqueda_binaria(lista,objetivo, punto_medio+1, limite_superior)
    
    
if __name__=='__main__':
    #crear una lista ordenada aleatoria de 10000 elementos
    tamano =10000
    conjunto_inicial =set()
    
    
    while len(conjunto_inicial) < tamano:
        conjunto_inicial.add(random.randint(-3*tamano,3*tamano))
    
    lista_ordenada = sorted(list(conjunto_inicial))
    
    # medir el tiempo de busqueda ingenua
    
    inicio = time.time()
    for objetivo in lista_ordenada:
        busqueda_ingenua(lista_ordenada, objetivo)
    fin= time.time()
    print(f"Tiempo de busqueda ingenua:{fin - inicio} segundos.")
     
    
    #medir el tiempo de busqueda binaria
    inicio = time.time()
    for objetivo in lista_ordenada:
        busqueda_binaria(lista_ordenada, objetivo)
    fin= time.time()
    print(f"Tiempo de busqueda binaria:{fin - inicio} segundos.")
# Out:
# Tiempo de busqueda ingenua:2.256458282470703 segundos.
# Tiempo de busqueda binaria:0.03364300727844238 segundos.

# %% [markdown]
# #### Realizar la prueba con ambos códigos con 20 000 elementos

# %%
def busqueda_binaria(lista, objetivo, limite_inferior=None, limite_superior=None):
    if limite_inferior is None:
        limite_inferior = 0 # inicio de la lista
    if limite_superior is None:
        limite_superior = len(lista)-1 # Final de las lista 
        
    if limite_superior < limite_inferior:
        return -1

    punto_medio = (limite_inferior + limite_superior) //2   # permite buscar el punto medio de la lista
    
    if lista[punto_medio] == objetivo:
        return punto_medio
    elif objetivo < lista[punto_medio]:
        return busqueda_binaria(lista,objetivo, limite_inferior,punto_medio-1)
    else:
        return busqueda_binaria(lista,objetivo, punto_medio+1, limite_superior)
    
    
if __name__=='__main__':
    #crear una lista ordenada aleatoria de 20000 elementos
    tamano =20000
    conjunto_inicial =set()
    
    
    while len(conjunto_inicial) < tamano:
        conjunto_inicial.add(random.randint(-3*tamano,3*tamano))
    
    lista_ordenada = sorted(list(conjunto_inicial))
    
    # medir el tiempo de busqueda ingenua
    
    inicio = time.time()
    for objetivo in lista_ordenada:
        busqueda_ingenua(lista_ordenada, objetivo)
    fin= time.time()
    print(f"Tiempo de busqueda ingenua:{fin - inicio} segundos.")
     
    
    #medir el tiempo de busqueda binaria
    inicio = time.time()
    for objetivo in lista_ordenada:
        busqueda_binaria(lista_ordenada, objetivo)
    fin= time.time()
    print(f"Tiempo de busqueda binaria:{fin - inicio} segundos.")
# Out:
# Tiempo de busqueda ingenua:12.672411918640137 segundos.
# Tiempo de busqueda binaria:0.11239266395568848 segundos.

# %% [markdown]
# #### Realizar una prueba del código de busqueda binaria con 100 000 elementos

# %%
def busqueda_binaria(lista, objetivo, limite_inferior=None, limite_superior=None):
    if limite_inferior is None:
        limite_inferior = 0 # inicio de la lista
    if limite_superior is None:
        limite_superior = len(lista)-1 # Final de las lista 
        
    if limite_superior < limite_inferior:
        return -1

    punto_medio = (limite_inferior + limite_superior) //2   # permite buscar el punto medio de la lista
    
    if lista[punto_medio] == objetivo:
        return punto_medio
    elif objetivo < lista[punto_medio]:
        return busqueda_binaria(lista,objetivo, limite_inferior,punto_medio-1)
    else:
        return busqueda_binaria(lista,objetivo, punto_medio+1, limite_superior)
    
    
if __name__=='__main__':
    #crear una lista ordenada aleatoria de 100000 elementos
    tamano =100000
    conjunto_inicial =set()
    
    
    while len(conjunto_inicial) < tamano:
        conjunto_inicial.add(random.randint(-3*tamano,3*tamano))
    
    lista_ordenada = sorted(list(conjunto_inicial))
    
   
    
    #medir el tiempo de busqueda binaria
    inicio = time.time()
    for objetivo in lista_ordenada:
        busqueda_binaria(lista_ordenada, objetivo)
    fin= time.time()
    print(f"Tiempo de busqueda binaria:{fin - inicio} segundos.")
# Out:
# Tiempo de busqueda binaria:0.7007589340209961 segundos.
